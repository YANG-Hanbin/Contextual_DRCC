# %%
using JuMP
using Gurobi
using LinearAlgebra
using DataFrames, PrettyTables

# Problem data
c = [25.0, 50.0]                     # cost vector
w = 1.0                              # target return
ε = 0.05                             # violation probability
θ = 0.1                              # Wasserstein radius
x0 = 1.3                             # contextual feature realization

# mean and covariance
μ = [0.95, 0.88, 1.45]              # [X, Y1, Y2]
Σ = [ 1.0   0.20   0.30;
      0.20   0.50   0.25;
      0.30   0.25   0.80 ]           # full covariance
# Out:
# 3×3 Matrix{Float64}:
#  1.0  0.2   0.3
#  0.2  0.5   0.25
#  0.3  0.25  0.8

# %%
using Distributions, Random, Statistics
Random.seed!(1)
mv_normal = MvNormal(μ, Σ)
data = rand(mv_normal, 100)
μ̂ = vec(mean(data, dims=2))

dist = sqrt(norm(μ̂ - μ))
# Out:
# 0.24787074199274664

# %%
# partition Σ and μ
μ̂X = μ̂[1]
μ̂Y = μ̂[2:3]
ΣXX = Σ[1, 1]
ΣXY = Σ[1, 2:3]
ΣYX = Σ[2:3, 1]
ΣYY = Σ[2:3, 2:3]

# conditional mean & covariance terms
A = ΣYX / ΣXX
ΣY_given_X = ΣYY .- ΣYX * ΣYX' ./ ΣXX
μY_given_X = μ[2:3] .+ ΣYX * inv(ΣXX) * (x0 - μ[1])
L = cholesky(Symmetric(ΣY_given_X)).L  # Cholesky factor
L2 = cholesky(Symmetric(ΣYY)).L  # Cholesky factor

Φinv = quantile(Normal(), ε)      # quantile of N(0,1), i.e. Φ^{-1}(ε)
# Out:
# -1.6448536269514729

# %%
cond_dist = MvNormal(μY_given_X, ΣY_given_X)
Random.seed!(2)
out_of_sample_data = rand(cond_dist, 10000)
# Out:
# 2×10000 Matrix{Float64}:
#  -0.00680161  1.35536  0.513005   0.797689  …  0.887506  0.136493  1.46637
#   0.207381    1.62912  2.37213   -0.457829     2.28919   2.0735    0.607059

# %%
results = DataFrame(
    epsilon = Float64[],
    theta = Float64[],
    opt_value = Any[],
    satisfaction = Any[],
    contextual_opt_value = Any[],
    contextual_satisfaction = Any[]
)

for ε in [0.05, 0.07, 0.09, 0.1]
    for θ in [0.01, 0.05, 0.1, 0.2]
        Φinv = quantile(Normal(), ε)      # quantile of N(0,1), i.e. Φ^{-1}(ε)

        ## Contextual Model
        model = Model(Gurobi.Optimizer)

        @variable(model, z[1:2] ≥ 0)
        @variable(model, t1 ≥ 0)
        @variable(model, t2 ≥ 0)

        # @constraint(model, sum(z) ≥ .1)
        # Robust chance constraint reformulation
        @constraint(model,
            dot(z, μ̂Y) + dot(z, A) * (x0 - μ̂X) - θ * t1 ≥ w - Φinv * t2
        )

        # SOC constraints
        @constraint(model, [t1, z[1], z[2]] in SecondOrderCone())
        @constraint(model, [t2; L * z] in SecondOrderCone())

        # Objective
        @objective(model, Min, dot(c, z))

        optimize!(model)
        if termination_status(model) == MOI.OPTIMAL
            contextual_opt_value = objective_value(model)

            # Out of sample satisfaction
            ẑ = value.(z)
            n_samples = size(out_of_sample_data, 2)
            count = 0

            for i in 1:n_samples
                if dot(out_of_sample_data[:, i], ẑ) ≥ w
                    count += 1
                end
            end

            contextual_satisfaction = count / n_samples
        else
            contextual_opt_value = nothing 
            contextual_satisfaction = nothing
        end

        ## Nominal Model
        model = Model(Gurobi.Optimizer)

        @variable(model, z[1:2] ≥ 0)
        @variable(model, t1 ≥ 0)
        @variable(model, t2 ≥ 0)

        # @constraint(model, sum(z) ≥ .1)
        # Robust chance constraint reformulation
        @constraint(model,
            dot(z, μ̂Y) - θ * t1 ≥ w - Φinv * t2
        )

        # SOC constraints
        @constraint(model, [t1, z[1], z[2], dot(z, A)] in SecondOrderCone())
        @constraint(model, [t2; L2 * z] in SecondOrderCone())

        # Objective
        @objective(model, Min, dot(c, z))

        optimize!(model)

        
        if termination_status(model) == MOI.OPTIMAL
            opt_value = objective_value(model)

            # Out of sample satisfaction
            ẑ = value.(z)
            n_samples = size(out_of_sample_data, 2)
            count = 0

            for i in 1:n_samples
                if dot(out_of_sample_data[:, i], ẑ) ≥ w
                    count += 1
                end
            end

            satisfaction = count / n_samples
        else
            opt_value = nothing 
            satisfaction = nothing
        end
        
        push!(results, (ε, θ, opt_value, satisfaction, contextual_opt_value, contextual_satisfaction))
    end
end
# Out:
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M3 Max
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 4 rows, 7 columns and 11 nonzeros
# Model fingerprint: 0xce107965
# Model has 2 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e+01, 5e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 2 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 6 columns, 9 nonzeros
# Presolved model has 2 second-order cone constraints
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.000e+00
#  Factor NZ  : 6.000e+00
#  Factor Ops : 1.400e+01 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.02383718e+01  1.02383718e+01  2.22e+00 4.87e+01  1.81e+01     0s
#    1   1.69460644e+01  4.78930909e+01  1.20e+00 2.73e+00  4.67e+00     0s
#    2   7.04269527e+01  1.25125281e+02  8.10e-01 1.55e+00  6.37e+00     0s
#    3   1.76733786e+02  1.46595563e+02  8.03e-03 1.54e-02  3.49e+00     0s
#    4   1.55171545e+02  1.53986773e+02  2.33e-05 2.54e-04  1.32e-01     0s
#    5   1.54945466e+02  1.54793767e+02  9.12e-06 2.65e-08  1.70e-02     0s
#    6   1.54821517e+02  1.54813112e+02  5.44e-07 9.43e-10  9.43e-04     0s
#    7   1.54815361e+02  1.54814238e+02  3.97e-08 5.38e-09  1.25e-04     0s
#    8   1.54814497e+02  1.54814426e+02  1.65e-09 1.91e-08  7.94e-06     0s
#    9   1.54814459e+02  1.54814458e+02  5.41e-09 9.92e-08  9.44e-09     0s
#
# Barrier solved model in 9 iterations and 0.00 seconds (0.00 work units)
# Optimal objective 1.54814459e+02
#
#
# User-callback calls 80, time in user-callback 0.00 sec
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M3 Max
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 8 rows, 11 columns and 20 nonzeros
# Model fingerprint: 0x7a90bac1
# Model has 2 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e-02, 2e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e+01, 5e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 7 columns, 12 nonzeros
# Presolved model has 2 second-order cone constraints
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.000e+00
#  Factor NZ  : 1.000e+01
#  Factor Ops : 3.000e+01 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.92946823e+00  6.92946823e+00  1.22e+00 5.11e+01  1.21e+01     0s
#    1   1.16138819e+01  5.77939441e+01  6.96e-01 4.31e+00  3.48e+00     0s
#    2   1.38882329e+01  2.72119787e+02  6.04e-01 2.13e+00  2.07e+00     0s
#    3   8.18839017e+02  4.11061333e+01  6.64e-07 1.93e+00  8.79e+01     0s
#    4   3.76761905e+02  1.44754869e+02  2.52e-07 5.38e-04  2.32e+01     0s
#    5   3.49745940e+02  3.12838338e+02  1.94e-13 5.92e-10  3.69e+00     0s
#    6   3.26591002e+02  3.24964383e+02  5.99e-13 8.03e-11  1.63e-01     0s
#    7   3.25563353e+02  3.25558578e+02  1.63e-11 9.07e-10  4.78e-04     0s
#    8   3.25560249e+02  3.25560243e+02  3.38e-09 5.88e-07  6.01e-07     0s
#
# Barrier solved model in 8 iterations and 0.00 seconds (0.00 work units)
# Optimal objective
iterations and 0.00 seconds (0.00 work units)
# Optimal objective 9.48043802e+01
#
#
# User-callback calls 78, time in user-callback 0.00 sec
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M3 Max
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 8 rows, 11 columns and 20 nonzeros
# Model fingerprint: 0x8d886da6
# Model has 2 quadratic constraints
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e+01, 5e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 7 columns, 12 nonzeros
# Presolved model has 2 second-order cone constraints
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.000e+00
#  Factor NZ  : 1.000e+01
#  Factor Ops : 3.000e+01 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8.17996196e+00  8.17996196e+00  1.22e+00 4.86e+01  1.31e+01     0s
#    1   1.43396613e+01  5.92042570e+01  6.80e-01 4.12e+00  3.47e+00     0s
#    2   3.32326953e+02  1.23284412e+02  7.48e-07 2.97e+00  2.68e+01     0s
#    3   1.43462902e+02  1.25764152e+02  5.91e-08 3.26e-06  1.77e+00     0s
#    4   1.37337954e+02  1.36403786e+02  2.33e-13 2.14e-11  9.34e-02     0s
#    5   1.36712107e+02  1.36696771e+02  1.98e-12 6.07e-11  1.53e-03     0s
#    6   1.36703357e+02  1.36702819e+02  1.12e-10 6.19e-09  5.38e-05     0s
#    7   1.36703019e+02  1.36702973e+02  2.80e-10 1.53e-08  4.57e-06     0s
#    8   1.36702987e+02  1.36702979e+02  2.39e-09 5.09e-09  8.40e-07     0s
#
# Barrier solved model in 8 iterations and 0.00 seconds (0.00 work units)
# Optimal objective 1.36702987e+02
#
#
# User-callback calls 83, time in user-callback 0.00 sec
# [0.6839928419426483, 2.3920633154757014]Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M3 Max
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 4 rows, 7 columns and 11 nonzeros
# Model fingerprint: 0xf679653a
# Model has 2 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e-01, 2e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e+01, 5e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 2 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 6 columns, 9 nonzeros
# Presolved model has 2 second-order cone constraints
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.000e+00
#  Factor NZ  : 6.000e+00
#  Factor Ops : 1.400e+01 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.22025125e+01  1.22025125e+01  1.92e+00 4.42e+01  1.65e+01     0s
#    1   1.94485024e+01  5.87491742e+01  1.07e+00 1.95e+00  3.92e+00     0s
#    2   2.49303757e+02  4.30530513e+01  5.19e-03 1.15e+00  2.49e+01     0s
#    3   1.10597924e+02  9.88372397e+01  1.22e-03 1.27e-06  1.32e+00     0s
#    4   1.03941113e+02  1.03541912e+02  2.03e-06 1.32e-12  4.44e-02     0s
#    5   1.03599658e+02  1.03593792e+02  3.11e-08 3.52e-11  6.52e-04     0s
#    6   1.03596142e+02  1.03595300e+02  5.94e-09 2.70e-09  9.37e-05     0s
#    7   1.03595829e+02  1.03595638e+02  1.98e-09 8.14e-09  2.13e-05     0s
#    8   1.03595745e+02  1.03595683e+02  4.25e-09 7.80e-09  6.96e-06     0s
#    9   1.03595694e+02  1.03595692e+02  8.38e-09 1.98e-09  2.94e-07     0s
#
# Barrier solved model in 9 iterations and 0.00 seconds (0.00 work units)
# Optimal objective 1.03595694e+02
#
#
# User-callback calls 80, time in user-callback 0.00 sec
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M3 Max
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 8 rows, 11 columns and 20 nonzeros
# Model fingerprint: 0x01943db1
# Model has 2 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e-01, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e+01, 5e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 7 columns, 12 nonzeros
# Presolved model has 2 second-order cone constraints
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.000e+00
#  Factor NZ  : 1.000e+01
#  Factor Ops : 3.000e+01 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8
#    5   8.70629608e+01  8.70612199e+01  6.89e-10 1.01e-10  1.93e-04     0s
#    6   8.70622264e+01  8.70620527e+01  7.85e-12 5.24e-10  1.93e-05     0s
#    7   8.70621145e+01  8.70620780e+01  1.75e-11 6.02e-09  4.05e-06     0s
#    8   8.70620908e+01  8.70620857e+01  3.30e-10 1.11e-08  5.68e-07     0s
#
# Barrier solved model in 8 iterations and 0.00 seconds (0.00 work units)
# Optimal objective 8.70620908e+01
#
#
# User-callback calls 78, time in user-callback 0.00 sec
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M3 Max
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 8 rows, 11 columns and 20 nonzeros
# Model fingerprint: 0x551edcea
# Model has 2 quadratic constraints
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e+01, 5e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 7 columns, 12 nonzeros
# Presolved model has 2 second-order cone constraints
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.000e+00
#  Factor NZ  : 1.000e+01
#  Factor Ops : 3.000e+01 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8.40397235e+00  8.40397235e+00  1.21e+00 4.81e+01  1.34e+01     0s
#    1   1.49345344e+01  5.86783971e+01  6.69e-01 4.35e+00  3.46e+00     0s
#    2   2.93368770e+02  1.10977632e+02  7.36e-07 3.15e+00  2.38e+01     0s
#    3   1.26994786e+02  1.11114706e+02  5.34e-08 3.47e-06  1.59e+00     0s
#    4   1.21060955e+02  1.20180610e+02  7.02e-11 4.29e-12  8.80e-02     0s
#    5   1.20590917e+02  1.20558286e+02  3.12e-12 1.21e-11  3.26e-03     0s
#    6   1.20569252e+02  1.20567874e+02  8.29e-11 2.23e-10  1.38e-04     0s
#    7   1.20568290e+02  1.20568207e+02  2.02e-10 5.76e-09  8.27e-06     0s
#    8   1.20568233e+02  1.20568227e+02  2.11e-10 1.02e-08  5.99e-07     0s
#
# Barrier solved model in 8 iterations and 0.00 seconds (0.00 work units)
# Optimal objective 1.20568233e+02
#
#
# User-callback calls 83, time in user-callback 0.00 sec
# [0.6196958666292449, 2.101516731309075]Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M3 Max
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 4 rows, 7 columns and 11 nonzeros
# Model fingerprint: 0x81b74bf3
# Model has 2 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e-01, 2e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e+01, 5e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 2 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 6 columns, 9 nonzeros
# Presolved model has 2 second-order cone constraints
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.000e+00
#  Factor NZ  : 6.000e+00
#  Factor Ops : 1.400e+01 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.26210976e+01  1.26210976e+01  1.84e+00 4.37e+01  1.62e+01     0s
#    1   2.00991219e+01  6.05310372e+01  1.03e+00 2.28e+00  3.72e+00     0s
#    2   1.82203990e+02  5.08805183e+01  4.13e-03 5.31e-01  1.53e+01     0s
#    3   9.90548603e+01  8.97937987e+01  7.80e-04 5.85e-07  1.04e+00     0s
#    4   9.44822110e+01  9.43246891e+01  1.50e-06 1.06e-08  1.75e-02     0s
#    5   9.44196418e+01  9.44170932e+01  3.87e-08 8.75e-11  2.84e-04     0s
#    6   9.44179249e+01  9.44178661e+01  8.94e-10 6.10e-11  6.54e-06     0s
#    7   9.44179153e+01  9.44179115e+01  9.64e-11 5.33e-09  4.28e-07     0s
#
# Barrier solved model in 7 iterations and 0.00 seconds (0.00 work units)
# Optimal objective 9.44179153e+01
#
#
# User-callback calls 76, time in user-callback 0.00 sec
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M3 Max
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 8 rows, 11 columns and 20 nonzeros
# Model fingerprint: 0x9c952747
# Model has 2 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e-01, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e+01, 5e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 7 columns, 12 nonzeros
# Presolved model has 2 second-order cone constraints
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.000e+00
#  Factor NZ  : 1.000e+01
#  Factor Ops : 3.000e+01 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8
iterations and 0.00 seconds (0.00 work units)
# Optimal objective 1.84584300e+02
#
#
# User-callback calls 85, time in user-callback 0.00 sec
# [1.0411559576279754, 3.171108011188493]

# %%
results
# Out:
# 16×6 DataFrame
#  Row │ epsilon  theta    opt_value  satisfaction  contextual_opt_value  contex ⋯
#      │ Float64  Float64  Any        Any           Any                   Any    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │    0.05     0.01  325.56     0.9623        154.814               0.9456 ⋯
#    2 │    0.05     0.05  435.375    0.9663        174.171               0.9499
#    3 │    0.05     0.1   751.685    0.9713        206.421               0.9561
#    4 │    0.05     0.2                            327.727               0.9661
#    5 │    0.07     0.01  170.725    0.9461        109.548               0.9241 ⋯
#    6 │    0.07     0.05  196.659    0.9512        118.884               0.9297
#    7 │    0.07     0.1   242.647    0.9566        133.055               0.9379
#    8 │    0.07     0.2   454.861    0.9673        174.69                0.9508
#    9 │    0.09     0.01  123.679    0.9288        88.7766               0.9061 ⋯
#   10 │    0.09     0.05  136.703    0.9354        94.8044               0.9112
#   11 │    0.09     0.1   157.385    0.9442        103.596               0.919
#   12 │    0.09     0.2   225.453    0.9565        127.179               0.9362
#   13 │    0.1      0.01  110.334    0.9207        81.9539               0.8934 ⋯
#   14 │    0.1      0.05  120.568    0.9268        87.0621               0.9038
#   15 │    0.1      0.1   136.353    0.9358        94.4179               0.911
#   16 │    0.1      0.2   184.584    0.9504        113.615               0.9275
#                                                                 1 column omitted

# %%
# latex_table = pretty_table(results; backend = Val(:latex))
io = IOBuffer()

pretty_table(
    io,
    results;
    backend = Val(:latex),
    formatters = ft_printf("%.2f", 1:ncol(results))  # 所有列保留两位小数
)

latex_code = String(take!(io))
println(latex_code)
# Out:
# \begin{tabular}{rrrrrr}
#   \hline
#   \textbf{epsilon} & \textbf{theta} & \textbf{opt\_value} & \textbf{satisfaction} & \textbf{contextual\_opt\_value} & \textbf{contextual\_satisfaction} \\
#   \texttt{Float64} & \texttt{Float64} & \texttt{Any} & \texttt{Any} & \texttt{Any} & \texttt{Any} \\\hline
#   0.05 & 0.01 & 325.56 & 0.96 & 154.81 & 0.95 \\
#   0.05 & 0.05 & 435.38 & 0.97 & 174.17 & 0.95 \\
#   0.05 & 0.10 & 751.69 & 0.97 & 206.42 & 0.96 \\
#   0.05 & 0.20 & nothing & nothing & 327.73 & 0.97 \\
#   0.07 & 0.01 & 170.73 & 0.95 & 109.55 & 0.92 \\
#   0.07 & 0.05 & 196.66 & 0.95 & 118.88 & 0.93 \\
#   0.07 & 0.10 & 242.65 & 0.96 & 133.06 & 0.94 \\
#   0.07 & 0.20 & 454.86 & 0.97 & 174.69 & 0.95 \\
#   0.09 & 0.01 & 123.68 & 0.93 & 88.78 & 0.91 \\
#   0.09 & 0.05 & 136.70 & 0.94 & 94.80 & 0.91 \\
#   0.09 & 0.10 & 157.38 & 0.94 & 103.60 & 0.92 \\
#   0.09 & 0.20 & 225.45 & 0.96 & 127.18 & 0.94 \\
#   0.10 & 0.01 & 110.33 & 0.92 & 81.95 & 0.89 \\
#   0.10 & 0.05 & 120.57 & 0.93 & 87.06 & 0.90 \\
#   0.10 & 0.10 & 136.35 & 0.94 & 94.42 & 0.91 \\
#   0.10 & 0.20 & 184.58 & 0.95 & 113.61 & 0.93 \\\hline
# \end{tabular}
